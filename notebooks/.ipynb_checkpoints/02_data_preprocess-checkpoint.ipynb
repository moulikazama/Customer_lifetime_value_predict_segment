# %% [markdown]
# # Data Preprocessing CLV

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/Online Retail.csv", encoding="ISO-8859-1")

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ### Handling Null Values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
#  **We can't assume the CustomerID. So, removing is only option.**

# %%
df = df.dropna(subset=["CustomerID"])

# %% [markdown]
# ### Handling Duplicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(5225)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Handing Non Positive Numbers

# %% [markdown]
# **Cancelled product are consider as negative values**

# %%
neg_df = df[df['Quantity'] <0]

# %%
neg_df.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 141  01-12-2010 09:41      27.50     14527.0  United Kingdom
# 154  01-12-2010 09:49       4.65     15311.0  United Kingdom
# 235  01-12-2010 10:24       1.65     17548.0  United Kingdom
# 236  01-12-2010 10:24       0.29     17548.0  United Kingdom
# 237  01-12-2010 10:24       0.29     17548.0  United Kingdom

# %%
df = df[df["Quantity"] > 0]

# %% [markdown]
# **Free Product Has no effect.So, remove those.**

# %%
df = df[df["UnitPrice"] > 0]

# %% [markdown]
# ### Total Revenue for Calculating CLV

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"]

# %% [markdown]
# **CustomerID is in Obj, need to be in Numeric**

# %%
df["CustomerID"] = df["CustomerID"].astype(int)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID        Revenue
# count  392692.000000  392692.000000  392692.000000  392692.000000
# mean       13.119702       3.125914   15287.843865      22.631500
# std       180.492832      22.241836    1713.539549     311.099224
# min         1.000000       0.001000   12346.000000       0.001000
# 25%         2.000000       1.250000   13955.000000       4.950000
# 50%         6.000000       1.950000   15150.000000      12.450000
# 75%        12.000000       3.750000   16791.000000      19.800000
# max     80995.000000    8142.750000   18287.000000  168469.600000

# %%
df.shape
# Out:
# (392692, 9)

# %% [markdown]
# #### InvoiceDate (dd/mm/yyyy/hh/MM) to (yyyy/mm/dd/hh/MM)

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"],dayfirst = True)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34

# %% [markdown]
# ### Check StockCode for Non-Real product.

# %%
df[~df["StockCode"].str.isnumeric()]["StockCode"].unique()
# Out:
# array(['85123A', '84406B', '84029G', '84029E', 'POST', '82494L', '85099C',
#        '84997B', '84997C', '84519A', '85183B', '85071B', '37444A',
#        '37444C', '84971S', '15056BL', '15056N', '85049A', '85099B',
#        '35004C', '35004G', '85014B', '85014A', '84970S', '84030E',
#        '35004B', '85049E', '17091A', '84509A', '84510A', '84709B',
#        '84625C', '84625A', '47570B', '85049C', '85049D', '85049G',
#        '84970L', '90199C', '90129F', '90210B', '72802C', '85169B',
#        '85099F', '85184C', '35591T', '84032B', '85049H', '72800E',
#        '84849B', '90200B', '90059B', '90185C', '90059E', '90059C',
#        '90200C', '90200D', '90200A', '16258A', '85231B', '85231G',
#        '48173C', '47563A', '84558A', '46000M', '71406C', '84985A',
#        '84596E', '84997D', '47599A', '47599B', '85035B', '84968C',
#        '72800B', '84563A', '47504H', '17164B', '15044B', '84569B',
#        '85114B', '85114C', '85199L', '85199S', '85019A', '85019C',
#        '85071A', '85071C', '85135B', '85136A', '85136C', 'C2', '79144B',
#        '46000R', '46000S', '84508A', '85232B', '79066K', '84884A',
#        '51014C', '51014L', '51014A', '79302M', '84509B', '84870C',
#        '84870B', 'M', '85032D', '84760S', '35598D', '35598B', '15056P',
#        '84032A', '84031A', '84997A', '90214M', '90214V', '90214S',
#        '90214J', '72807C', '47591B', '85035C', '72803A', '85034A',
#        '72798C', '35271S', '47567B', '72760B', '62096A', '85071D',
#        '79191C', '84031B', '47566B', '47590B', '47590A', '85061W',
#        '47591D', '84341B', '84509G', '84846A', '85132A', '85132B',
#        '85132C', '85159A', '17090D', '17090A', '10124G', '84519B',
#        '90175C', '90180A', '90178A', '85025C', '85124B', '85124C',
#        '16156S', '85049F', '90082D', '90082A', '90082B', '90081A',
#        '90185B', '90195A', '90195B', '90196A', '90199A', '90177C',
#        '90186A', '18097A', '18097C', '85185D', '85185B', '15060B',
#        '85114A', '72801C', '72801D', 'BANK CHARGES', '84952C', '84952B',
#        '35001G', '90002D', '47559B', '16161P', '16161M', '84247G',
#        '47021G', '85049B', '85131A', '10123C', '84993A', '84925D',
#        '84520B', '17084R', '17091J', '85018D', '47503J', '84247N',
#        '84247K', '47504K', '37489D', '17107D', '37489B', '37489C',
#        '37489A', '84534B', '84536A', '85130A', '85129C', '84849A',
#        '84559A', '84559B', '85230B', '85230F', '84849D', '84507C',
#        '82616C', '82616B', '90128B', '90196B', '90198B', '90152B',
#        '84877D', '47503H', '47343A', '72802A', '72807B', '72802B',
#        '84562A', '82011C', '85036B', '85035A', '85034C', '84614A',
#        '85135C', '84924A', '35810B', '17109D', '85034B', '72800D',
#        '90185D', '90175A', '90162B', '90162D', '84898F', '47310M',
#        '84508B', '84279P', '84963A', '72349B', '84993B', '85206A',
#        '84536B', '84596G', '77101A', '79149B', '78034B', '79151B',
#        '35471D', '85130D', '84569D', '72351A', '84508C', '85179A',
#        '84874B', '85167B', '72051S', '72799E', '72799F', '84535B',
#        '75013B', '82011B', '84563B', '82613B', '79190A', '47593B',
#        '85129D', '85129B', '84968A', '47369A', '47369B', '47367B',
#        '16161U', '84597C', '51020A', '51020B', '90200E', '84596L',
#        '84596F', '18098C', '85036C', '85170D', '84531A', '84531B',
#        '84809A', '79190D', '84795B', '79191B', '85027L', '85017C',
#        '35001W', '84707B', '72807A', '84968F', '79030D', '37479B',
#        '37482P', '47594A', '84926D', '84926A', '72801G', '84711A',
#        '16169N', '35597A', '35597B', '84596B', '79030G', '72351B',
#        '84912A', '85036A', '84569A', '90179C', '90060D', '79051A',
#        '85169A', '17007B', '10124A', '46000P', '40005B', '18094C',
#        '47586A', '46115B', '15044C', '84925F', '16169K', '84707A',
#        '47574A', '37479P', '84912B', '17084J', '84968D', '85232D',
#        '84247E', '85170B', '84596J', '85170A', '85026B', '90175D',
#        '82001S', '90212B', '90212C', '47348A', '90214C', '90214B',
#        '90214K', '85039C', '85024C', '84613C', '84910A', '90184B',
#        '90184A', '84415B', '71496A', '71495B', '85230G', '35833P',
#        '16168M', '84952A', '84706D', '84247L', '85170C', '84875B',
#        '84876D', '90211B', '79190B', '90036D', '37444B', '85039B',
#        '85040B', '17084N', '17084P', '84913B', '84913A', '85032A',
#        '85032C', '47578A', '84951A', '84951B', '17165D', '15058A',
#        '16169P', '90081C', '84595E', '84459B', '35915B', '85086A',
#        '81950V', '17012D', '17012B', '17012E', '17012F', '35004P',
#        '15058B', '85230E', '84509C', '90186B', '90190C', '90003D',
#        '90003C', '90067A', '90003B', '85032B', '85017B', '47593A',
#        '85136B', '85031A', '84660B', '85040A', '90036E', '90160A',
#        '90160B', '90161B', '90160C', '90160D', '82011A', '85183A',
#        '35610B', '35610C', '84927E', '90129A', '90120D', '90162C',
#        '90014B', '84575A', '84313C', '84313B', '90125D', '90210A',
#        '85169D', '90210C', '90210D', '35095B', '84927A', '85194L',
#        '84660A', '84509E', '82613C', '47503A', '90125A', '85180B',
#        '85180A', '85159B', '84660C', '90058B', '84597B', '62094B',
#        '84673A', '84673B', '17013D', '82613D', '90185A', '90161D',
#        '90161C', '90129C', '90129B', '85039A', '35610A', '35817P',
#        '35599B', '90042A', '90060B', '90035A', '90179A', '84751B',
#        '84507B', '17012C', '17014A', '17012A', '47594B', '90209C',
#        '84877B', '84078A', '84926F', '35911A', '85031C', '84613A',
#        '85169C', '84750B', '72800C', '17011F', '35809A', '35810A',
#        '35607A', '84859A', '85031B', '85205B', '85163A', '85163B',
#        '85232A', '46000U', '90177D', '90161A', '90177B', '90198A',
#        '90199D', '90014A', '90178B', '85023B', '84804A', '84800L',
#        '84800M', '84802A', '84806A', '16207A', '85130B', '84249A',
#        '90027A', '90027D', '90019A', '90040A', '90120C', '90040B',
#        '85230A', '90214D', '72225C', '82613A', '85135A', '15044A',
#        '84459A', '90165B', '16206B', '46138B', '47585A', '84926E',
#        '85194S', '35911B', '84989A', '84968E', '79071B', '16169M',
#        '84931A', '84931B', '35909A', '35910A', '84927F', '47518F',
#        '16156L', '85025B', '47351B', '84251B', '84251G', '84251C',
#        '84510C', '84741C', '90123B', '90123C', '90122A', '90184C',
#        '90122C', '75049L', '44091A', '85019B', '16207B', '47556B',
#        '79323P', '62086A', '35912B', '85206B', '84745A', '84745B',
#        '85186C', '90010B', '85186A', '90125B', '85131D', '85131C',
#        '85131B', '84806B', '85188B', '15044D', '35095A', '84796B',
#        '37379A', '90214R', '84510E', '84801A', '84927D', '84800S',
#        '79192A', '85130C', '40046A', '72799C', '71101E', '79191D',
#        '90214G', '46775D', '90197B', '90125C', '35913B', '90123D',
#        '90123A', '90010E', '90016B', '90016A', '85188A', '85160B',
#        '85024B', '71496B', '35915C', '17028J', '17084A', '84795C',
#        '62074B', '84279B', '84801B', '84805A', '17136A', '84712B',
#        '84708B', '44089A', '84086C', '84429A', '37462E', '90037B',
#        '15058C', '84659A', '35815P', '90202B', '90202C', '90039C',
#        '90120B', '90122B', '90010A', '79323B', '90064B', '90011B',
#        '90064A', '90063A', '90063B', '44089C', '35909B', '90180B',
#        '90152C', '90152A', '90018A', '84663A', '35637A', '84661C',
#        '84857C', '84859C', '79063D', '79062D', '47341A', '44092C',
#        '44092B', '90018B', '90065A', '90024F', '90026D', '90024C',
#        '90000B', '90000D', '90000A', '90026C', '90026B', '35638A',
#        '90209B', '84876B', '46776B', '35637C', '90214A', '84809B',
#        '84858C', '72140E', '35916C', '84802B', '84803B', '84798A',
#        '16020C', '46776C', '90141C', '90141A', '90183C', '90124B',
#        '79026B', '35607B', '84798B', '90040C', '90038B', '90038C',
#        '90214P', '35916A', '62096B', '16248B', '84086B', '79063C',
#        '84535A', '16202A', '17129F', '16161G', '90201B', '47013A',
#        '84968B', '35910B', '46776E', '84750A', '37488A', '47344B',
#        '46126A', '90036F', '90030B', '47013C', '84796A', '84569C',
#        '85028S', '85028L', '85017A', '90164A', '90124A', '90124C',
#        '84743C', '90014C', '35809B', '16202E', '84877A', '84875D',
#        '84872A', '90024D', '90001C', '90025A', '90142D', '37487B',
#        '44242B', '46776A', '46776F', '46776D', 'PADS', '16202B', '79144C',
#        '72024U', '90164B', '90163A', '90163B', '16244B', '47341B',
#        '62097B', '62043B', '90201D', '90201C', '90201A', '71495A',
#        '84705C', '90058A', '35599D', '84859B', '90036A', '90130B',
#        '90036C', '16151A', '90039D', '90039B', '90039A', '90035C',
#        '47574B', '84661A', '90214Y', '84873A', '84804B', '90202D',
#        '84984B', '84984A', '90013C', '90141B', '90125E', '84711B',
#        '84206C', '90059F', '90206C', '90206A', '35818P', '90214E',
#        '84661B', '84415A', '90214L', '90214N', '90214H', '16162L',
#        '90026A', '90036B', '90001A', '90001D', '90001B', '90190B',
#        '90190A', '90187B', '85168B', '72369A', '90176D', '81952B',
#        '81952V', '81950B', '90205C', '90205A', '84706F', '44242A',
#        '84924F', '81953B', '81953P', '90214I', '90030C', '90030A',
#        '90141D', '90141E', '37491D', '37491B', '37491C', '84402B',
#        '16162M', '84732D', '84732B', '84387A', '16169E', '84857B',
#        '35638B', '84984D', '85179C', '90019B', '84963B', '90209A',
#        '90013A', '35816P', '35597D', '35818B', '35916B', '84206A',
#        '84201B', '90176C', '90176E', '90003E', '90018C', '90024B',
#        '90211A', '84201C', 'DOT', '35819B', '90183A', '90019C', '90038A',
#        '35819P', '84805B', '90059A', '90059D', '90202A', '90177A',
#        '90177E', '90182C', '90129D', '90129E', '90012A', '79157V',
#        '90189A', '90012B', '90025F', '79157B', '90181A', '90199B',
#        '90176A', '90176B', '90162A', '79161A', '90065B', '17191A',
#        '35598C', '35598A', '84206B', '90130A', '90011A', '90214F',
#        '90214O', '90214T', '90214U', '90214W', '90214Z'], dtype=object)

# %%
remove_codes = ["POST", "M", "C2", "DOT", "PADS", "BANK CHARGES"]

df = df[~df["StockCode"].isin(remove_codes)]

# %% [markdown]
# ### Checking for outliers

# %% [markdown]
# **Quantity Outliers**

# %%
plt.figure()
plt.boxplot(df["Quantity"])
plt.title("Box Plot of Quantity")
plt.show()

# %%
ls1=[]
top_10 = df['Quantity'].nlargest(n=10)
for i in top_10:
    ls1.append(i)

# %%
high_quantity = df[df['Quantity'].isin(ls1)]
high_quantity.sort_values('Quantity',ascending = False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 433788    573995     16014          SMALL CHINESE STYLE SCISSOR      3000
# 4945      536830     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 291249    562439     84879        ASSORTED COLOUR BIRD ORNAMENT      2880
#
#                InvoiceDate  UnitPrice  CustomerID         Country    Revenue
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom  168469.60
# 61619  2011-01-18 10:01:00       1.04       12346  United Kingdom   77183.60
# 421632 2011-10-27 12:26:00       0.21       12901  United Kingdom    1008.00
# 206121 2011-05-27 10:52:00       0.72       13135  United Kingdom    3096.00
# 97432  2011-02-22 10:43:00       0.82       18087  United Kingdom    3202.92
# 270885 2011-07-19 17:04:00       0.06       14609  United Kingdom     191.16
# 52711  2011-01-11 12:55:00       2.10       15749  United Kingdom    6539.40
# 160546 2011-04-18 13:20:00       2.10       15749  United Kingdom    6539.40
# 433788 2011-11-02 11:24:00       0.32       16308  United Kingdom     960.00
# 4945   2010-12-02 17:38:00       0.18       16754  United Kingdom     518.40
# 291249 2011-08-04 18:06:00       1.45       12931  United Kingdom    4176.00

# %% [markdown]
# **UnitPrice Outlier**

# %%
plt.figure()
plt.boxplot(df["UnitPrice"])
plt.title("Box Plot of UnitPrice")
plt.show()

# %%
ls2=[]
top_10 = df['UnitPrice'].nlargest(n=10)
for i in top_10:
    ls2.append(i)

# %%
high_unitprice = df[df['UnitPrice'].isin(ls2)]
high_unitprice.sort_values('UnitPrice',ascending = False)
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 222680    556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446     22502  PICNIC BASKET WICKER 60 PIECES         1
# 4989      536835     22655     VINTAGE RED KITCHEN CABINET         1
# 32484     539080     22655     VINTAGE RED KITCHEN CABINET         1
# 51636     540647     22655     VINTAGE RED KITCHEN CABINET         1
# 82768     543253     22655     VINTAGE RED KITCHEN CABINET         1
# 118769    546480     22656    VINTAGE BLUE KITCHEN CABINET         1
# 133994    547814     22656    VINTAGE BLUE KITCHEN CABINET         1
# 171178    551393     22656    VINTAGE BLUE KITCHEN CABINET         1
# 205759    554836     22655     VINTAGE RED KITCHEN CABINET         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 222680 2011-06-10 15:28:00      649.5       15098  United Kingdom  38970.0
# 222682 2011-06-10 15:33:00      649.5       15098  United Kingdom    649.5
# 4989   2010-12-02 18:06:00      295.0       13145  United Kingdom    295.0
# 32484  2010-12-16 08:41:00      295.0       16607  United Kingdom    295.0
# 51636  2011-01-10 14:57:00      295.0       17406  United Kingdom    295.0
# 82768  2011-02-04 15:32:00      295.0       14842  United Kingdom    295.0
# 118769 2011-03-14 11:38:00      295.0       13452  United Kingdom    295.0
# 133994 2011-03-25 14:19:00      295.0       13452  United Kingdom    295.0
# 171178 2011-04-28 12:22:00      295.0       14973  United Kingdom    295.0
# 205759 2011-05-26 16:25:00      295.0       13015  United Kingdom    295.0

# %% [markdown]
# **Revenue Outliers**

# %%
plt.figure()
plt.boxplot(df["Revenue"])
plt.title("Box Plot of Revenue")
plt.show()

# %%
ls3=[]
top_10 = df['Revenue'].nlargest(n=10)
for i in top_10:
    ls3.append(i)

# %%
high_unitprice = df[df['Revenue'].isin(ls3)]
high_unitprice.sort_values('Revenue',ascending = False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 222680    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 348325    567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 421601    573003     23084                   RABBIT NIGHT LIGHT      2400
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 160542    550461    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 52772     540818     48185                   DOORMAT FAIRY CAKE       670
#
#                InvoiceDate  UnitPrice  CustomerID         Country    Revenue
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom  168469.60
# 61619  2011-01-18 10:01:00       1.04       12346  United Kingdom   77183.60
# 222680 2011-06-10 15:28:00     649.50       15098  United Kingdom   38970.00
# 348325 2011-09-20 11:05:00       5.06       17450  United Kingdom    7144.72
# 52711  2011-01-11 12:55:00       2.10       15749  United Kingdom    6539.40
# 160546 2011-04-18 13:20:00       2.10       15749  United Kingdom    6539.40
# 421601 2011-10-27 12:11:00       2.08       14646     Netherlands    4992.00
# 52709  2011-01-11 12:55:00       2.55       15749  United Kingdom    4921.50
# 160542 2011-04-18 13:20:00       2.40       15749  United Kingdom    4632.00
# 52772  2011-01-11 12:57:00       6.75       15749  United Kingdom    4522.50

# %% [markdown]
# ### Check top 3 customer in top 10 revenue customer

# %%
df[df["CustomerID"] == 16446]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 194354    553573     22980       PANTRY SCRUBBING BRUSH         1
# 194355    553573     22982          PANTRY PASTRY BRUSH         1
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country    Revenue
# 194354 2011-05-18 09:52:00       1.65       16446  United Kingdom       1.65
# 194355 2011-05-18 09:52:00       1.25       16446  United Kingdom       1.25
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom  168469.60

# %%
df[df["CustomerID"] == 12346]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 61619 2011-01-18 10:01:00       1.04       12346  United Kingdom  77183.6

# %%
df[df["CustomerID"] == 15098]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 222670    556442     22502      PICNIC BASKET WICKER SMALL        60
# 222680    556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446     22502  PICNIC BASKET WICKER 60 PIECES         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 222670 2011-06-10 15:22:00       4.95       15098  United Kingdom    297.0
# 222680 2011-06-10 15:28:00     649.50       15098  United Kingdom  38970.0
# 222682 2011-06-10 15:33:00     649.50       15098  United Kingdom    649.5

# %% [markdown]
# **From Quantity, UnitPrice, Revenue removing outliers**

# %%
Outliers = [581483,556444,541431] # Since Irregular purchase Invoice
df = df[~df['InvoiceNo'].isin(Outliers)]

# %% [markdown]
# ***Since those are Non regular Purchase***

# %% [markdown]
# ### EDA

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391150 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    391150 non-null  object
#  1   StockCode    391150 non-null  object
#  2   Description  391150 non-null  object
#  3   Quantity     391150 non-null  int64
#  4   InvoiceDate  391150 non-null  datetime64[ns]
#  5   UnitPrice    391150 non-null  float64
#  6   CustomerID   391150 non-null  int64
#  7   Country      391150 non-null  object
#  8   Revenue      391150 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 37.9+ MB
#             Quantity                    InvoiceDate      UnitPrice  \
# count  391150.000000                         391150  391150.000000
# mean       13.145300  2011-07-10 19:37:34.766713600       2.874372
# min         1.000000            2010-12-01 08:26:00       0.040000
# 25%         2.000000            2011-04-07 11:16:00       1.250000
# 50%         6.000000            2011-07-31 12:05:00       1.950000
# 75%        12.000000            2011-10-20 12:57:00       3.750000
# max     80995.000000            2011-12-09 12:50:00     649.500000
# std       180.807831                            NaN       4.284738
#
#           CustomerID        Revenue
# count  391150.000000  391150.000000
# mean    15295.171456      22.337281
# min     12346.000000       0.060000
# 25%     13969.000000       4.950000
# 50%     15159.000000      11.900000
# 75%     16794.000000      19.800000
# max     18287.000000  168469.600000
# std      1710.339033     310.932442

# %% [markdown]
# **Top 10 Product with high revenue**

# %%
top_products = df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10)
top_products
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# REGENCY CAKESTAND 3 TIER              142264.75
# WHITE HANGING HEART T-LIGHT HOLDER    100392.10
# JUMBO BAG RED RETROSPOT                85040.54
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# PARTY BUNTING                          68785.23
# ASSORTED COLOUR BIRD ORNAMENT          56413.03
# RABBIT NIGHT LIGHT                     51251.24
# CHILLI LIGHTS                          46265.11
# PAPER CHAIN KIT 50'S CHRISTMAS         42584.13
# Name: Revenue, dtype: float64

# %% [markdown]
# **Top 10 CustomerID with high revenue**

# %%
top_customers = df.groupby("CustomerID")["Revenue"].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# CustomerID
# 14646    279138.02
# 18102    259657.30
# 17450    194390.79
# 16446    168472.50
# 14911    136161.83
# 12415    124564.53
# 14156    116560.08
# 17511     91062.38
# 12346     77183.60
# 16029     72708.09
# Name: Revenue, dtype: float64

# %% [markdown]
# **Top 10 Country with high revenue**

# %%
country_revenue = df.groupby("Country")["Revenue"].sum().sort_values(ascending=False)
country_revenue
# Out:
# Country
# United Kingdom          7242855.32
# Netherlands              283889.34
# EIRE                     257013.12
# Germany                  205381.15
# France                   183801.94
# Australia                138103.81
# Spain                     55706.56
# Switzerland               52441.95
# Japan                     37416.37
# Belgium                   36927.34
# Sweden                    36828.83
# Norway                    32454.64
# Portugal                  26643.90
# Channel Islands           19997.54
# Finland                   18344.88
# Denmark                   18211.34
# Italy                     15820.24
# Cyprus                    13167.16
# Singapore                  9120.39
# Austria                    8742.68
# Israel                     7215.84
# Poland                     6974.65
# Greece                     4425.52
# Iceland                    4310.00
# USA                        3580.39
# Canada                     3115.44
# Unspecified                2660.77
# Malta                      2070.59
# United Arab Emirates       1864.78
# Lebanon                    1693.88
# Lithuania                  1661.06
# European Community         1159.25
# Brazil                     1143.60
# RSA                        1002.31
# Czech Republic              786.74
# Bahrain                     548.40
# Saudi Arabia                145.92
# Name: Revenue, dtype: float64

# %%
df["YearMonth"] = df["InvoiceDate"].dt.to_period("M")

monthly_revenue = df.groupby("YearMonth")["Revenue"].sum()

monthly_revenue.plot()
# Out:
# <Axes: xlabel='YearMonth'>

# %%
import os
path = os.makedirs("../data/processed", exist_ok=True) # Create results directory if it doesn't exist
df.to_csv("../data/processed/cleaned_data.csv", index=False)

# %% [markdown]
# ## END of the Code
