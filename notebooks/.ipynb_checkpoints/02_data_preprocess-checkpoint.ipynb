# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Online Retail.csv", encoding="ISO-8859-1")

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# We can't assume the CustomerID.So, removing is only option.

# %%
df = df.dropna(subset=["CustomerID"])

# %%
df.duplicated().sum()
# Out:
# np.int64(5225)

# %%
df = df.drop_duplicates()

# %%
df = df[df["Quantity"] > 0]

# %%
df = df[df["UnitPrice"] > 0]

# %%
df["TotalPrice"] = df["Quantity"] * df["UnitPrice"]

# %%
df["CustomerID"] = df["CustomerID"].astype(int)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID     TotalPrice
# count  392692.000000  392692.000000  392692.000000  392692.000000
# mean       13.119702       3.125914   15287.843865      22.631500
# std       180.492832      22.241836    1713.539549     311.099224
# min         1.000000       0.001000   12346.000000       0.001000
# 25%         2.000000       1.250000   13955.000000       4.950000
# 50%         6.000000       1.950000   15150.000000      12.450000
# 75%        12.000000       3.750000   16791.000000      19.800000
# max     80995.000000    8142.750000   18287.000000  168469.600000

# %%
df.shape
# Out:
# (392692, 9)

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"],dayfirst = True)

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
#
#    Revenue
# 0    15.30
# 1    20.34
# 2    22.00
# 3    20.34
# 4    20.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392692 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392692 non-null  object
#  1   StockCode    392692 non-null  object
#  2   Description  392692 non-null  object
#  3   Quantity     392692 non-null  int64
#  4   InvoiceDate  392692 non-null  datetime64[ns]
#  5   UnitPrice    392692 non-null  float64
#  6   CustomerID   392692 non-null  int64
#  7   Country      392692 non-null  object
#  8   TotalPrice   392692 non-null  float64
#  9   Revenue      392692 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(4)
# memory usage: 33.0+ MB

# %%
df['InvoiceNo'].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       shape=(18532,), dtype=object)

# %%
df_cancel = ~df["InvoiceNo"].str.startswith("C")

# %%
df = df[~df["InvoiceNo"].str.startswith("C")]

# %%
df_cancel
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: InvoiceNo, Length: 392692, dtype: bool

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(df["Quantity"])
plt.title("Box Plot of Quantity")
plt.show()

# %%
plt.figure()
plt.boxplot(df["UnitPrice"])
plt.title("Box Plot of UnitPrice")
plt.show()

# %%
Q1 = df["Quantity"].quantile(0.25)
Q3 = df["Quantity"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Quantity"] < lower) | (df["Quantity"] > upper)]
outliers.shape
# Out:
# (25616, 10)

# %%
#handle outliers

# %%
upper_limit = df["Quantity"].quantile(0.99)
df[df["Quantity"] > upper_limit]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 178       536387     79321                      CHILLI LIGHTS       192
# 179       536387     22780     LIGHT GARLAND BUTTERFILES PINK       192
# 180       536387     22779         WOODEN OWLS LIGHT GARLAND        192
# 181       536387     22466      FAIRY TALE COTTAGE NIGHTLIGHT       432
# 182       536387     21731      RED TOADSTOOL LED NIGHT LIGHT       432
# ...          ...       ...                                ...       ...
# 540350    581476     72232            FENG SHUI PILLAR CANDLE       144
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 541545    581501     22319  HAIRCLIPS FORTIES FABRIC ASSORTED       180
# 541702    581566     23404         HOME SWEET HOME BLACKBOARD       144
# 541711    581567     21326   AGED GLASS SILVER T-LIGHT HOLDER       144
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %%
upper_rev = df["Revenue"].quantile(0.99)
df[df["Revenue"] > upper_rev]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 46        536371     22086  PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65        536374     21258       VICTORIAN SEWING BOX LARGE        32
# 178       536387     79321                    CHILLI LIGHTS       192
# 179       536387     22780   LIGHT GARLAND BUTTERFILES PINK       192
# 180       536387     22779       WOODEN OWLS LIGHT GARLAND        192
# ...          ...       ...                              ...       ...
# 540442    581487     21137         BLACK RECORD COVER FRAME       120
# 541222    581495    15056N        EDWARDIAN PARASOL NATURAL        36
# 541223    581495   15056BL          EDWARDIAN PARASOL BLACK        36
# 541702    581566     23404       HOME SWEET HOME BLACKBOARD       144
# 541892    581586     21217    RED RETROSPOT ROUND CAKE TINS        24
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %%
df[df["Quantity"] > upper_limit][["CustomerID","Quantity","UnitPrice","Revenue"]]
# Out:
#         CustomerID  Quantity  UnitPrice    Revenue
# 178          16029       192       3.82     733.44
# 179          16029       192       3.37     647.04
# 180          16029       192       3.37     647.04
# 181          16029       432       1.45     626.40
# 182          16029       432       1.25     540.00
# ...            ...       ...        ...        ...
# 540350       12433       144       0.19      27.36
# 540421       16446     80995       2.08  168469.60
# 541545       12985       180       0.19      34.20
# 541702       18102       144       3.26     469.44
# 541711       16626       144       0.55      79.20
#
# [3888 rows x 4 columns]

# %%
ls=[]
top_10 = df['Revenue'].nlargest(n=10)
for i in top_10:
    ls.append(i)

# %%
high_revenue = df[df['Revenue'].isin(ls)]
high_revenue
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 160542    550461    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 173382    551697      POST                              POSTAGE         1
# 222680    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 348325    567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
# 421601    573003     23084                   RABBIT NIGHT LIGHT      2400
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country    Revenue
# 52709   11-01-2011 12:55       2.55     15749.0  United Kingdom    4921.50
# ...

# %%
top_30
# Out:
# 540421    80995
# 61619     74215
# 421632     4800
# 206121     4300
# 97432      3906
# 270885     3186
# 52711      3114
# 160546     3114
# 433788     3000
# 4945       2880
# 291249     2880
# 201149     2700
# 80742      2592
# 32671      2400
# 87631      2400
# 91772      2400
# 421601     2400
# 125282     2160
# 437480     2100
# 511421     2040
# 52710      2000
# 160545     2000
# 177702     2000
# 311391     2000
# 424310     1992
# 348317     1944
# 348318     1944
# 52709      1930
# 160542     1930
# 291247     1900
# Name: Quantity, dtype: int64

# %%
s = [168469.60,74215]
fr = df[df['Quantity'].isin(s)]

# %%
fr
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 61619  2011-01-18 10:01:00       1.04       12346  United Kingdom     77183.6
# 540421 2011-12-09 09:15:00       2.08       16446  United Kingdom    168469.6
#
#          Revenue YearMonth
# 61619    77183.6   2011-01
# 540421  168469.6   2011-12

# %%
m = [8142.75,4161.06]
frf = df[df['UnitPrice'].isin(s)]

# %%
frf
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 173382    551697      POST     POSTAGE         1 2011-05-03 13:46:00
# 422351    573077         M      Manual         1 2011-10-27 14:13:00
# 422376    573080         M      Manual         1 2011-10-27 14:20:00
#
#         UnitPrice  CustomerID         Country  TotalPrice  Revenue YearMonth
# 173382    8142.75       16029  United Kingdom     8142.75  8142.75   2011-05
# 422351    4161.06       12536          France     4161.06  4161.06   2011-10
# 422376    4161.06       12536          France     4161.06  4161.06   2011-10

# %%
c = [12346,16446,16029,12536]
frm = df[df['CustomerID'].isin(c)]

# %%
frm
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 175       536386     84880           WHITE WIRE EGG HOLDER        36
# 176       536386    85099C  JUMBO  BAG BAROQUE BLACK WHITE       100
# 177       536386    85099B         JUMBO BAG RED RETROSPOT       100
# 178       536387     79321                   CHILLI LIGHTS       192
# 179       536387     22780  LIGHT GARLAND BUTTERFILES PINK       192
# ...          ...       ...                             ...       ...
# 431947    573774     23206          LUNCH BAG APPLE DESIGN        50
# 431948    573774     22961          JAM MAKING SET PRINTED        96
# 431949    573774     21931          JUMBO STORAGE BAG SUKI       100
# 431950    573774    85099F            JUMBO BAG STRAWBERRY       100
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 175     01-12-2010 09:57       4.95     16029.0  United Kingdom
# ...

# %%
c1 = df[df['CustomerID'].isin([12346])]
c1
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 61619  18-01-2011 10:01       1.04     12346.0  United Kingdom

# %%
c2 = df[df['CustomerID'].isin([16446])]
c2
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 194354    553573     22980       PANTRY SCRUBBING BRUSH         1
# 194355    553573     22982          PANTRY PASTRY BRUSH         1
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country    Revenue
# 194354  18-05-2011 09:52       1.65     16446.0  United Kingdom       1.65
# 194355  18-05-2011 09:52       1.25     16446.0  United Kingdom       1.25
# 540421  09-12-2011 09:15       2.08     16446.0  United Kingdom  168469.60

# %%
c3 = df[df['CustomerID'].isin([16029])]
c3
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 175       536386     84880            WHITE WIRE EGG HOLDER        36
# 176       536386    85099C   JUMBO  BAG BAROQUE BLACK WHITE       100
# 177       536386    85099B          JUMBO BAG RED RETROSPOT       100
# 178       536387     79321                    CHILLI LIGHTS       192
# 179       536387     22780   LIGHT GARLAND BUTTERFILES PINK       192
# ...          ...       ...                              ...       ...
# 431946    573774     22666  RECIPE BOX PANTRY YELLOW DESIGN        36
# 431947    573774     23206           LUNCH BAG APPLE DESIGN        50
# 431948    573774     22961           JAM MAKING SET PRINTED        96
# 431949    573774     21931           JUMBO STORAGE BAG SUKI       100
# 431950    573774    85099F             JUMBO BAG STRAWBERRY       100
#
#              InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
c4 = df[df['CustomerID'].isin([12536])]
c4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 391355    570672    17012A  ORIGAMI VANILLA INCENSE/CANDLE SET         24
# 391356    570672    17012B   ORIGAMI JASMINE INCENSE/CANDLE SET        24
# 391357    570672     20665                 RED RETROSPOT PURSE          6
# 391358    570672     20674                  GREEN POLKADOT BOWL        16
# 391359    570672     20675                   BLUE POLKADOT BOWL         8
# ...          ...       ...                                  ...       ...
# 391611    570672    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA        12
# 391612    570672    85199L  LARGE HANGING IVORY & RED WOOD BIRD        12
# 391613    570672     85227       SET OF 6 3D KIT CARDS FOR KIDS        12
# 422351    573077         M                               Manual         1
# 422376    573080         M                               Manual         1
#
#              InvoiceDate  UnitPrice  CustomerID Country  Revenue
# ...

# %%
df["StockCode"].unique()
# Out:
# array(['85123A', '71053', '84406B', ..., '90214Z', '90089', '23843'],
#       shape=(3665,), dtype=object)

# %%
#EDA

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392692 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392692 non-null  object
#  1   StockCode    392692 non-null  object
#  2   Description  392692 non-null  object
#  3   Quantity     392692 non-null  int64
#  4   InvoiceDate  392692 non-null  datetime64[ns]
#  5   UnitPrice    392692 non-null  float64
#  6   CustomerID   392692 non-null  int64
#  7   Country      392692 non-null  object
#  8   TotalPrice   392692 non-null  float64
#  9   Revenue      392692 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(4)
# memory usage: 33.0+ MB
#             Quantity                    InvoiceDate      UnitPrice  \
# count  392692.000000                         392692  392692.000000
# mean       13.119702  2011-07-10 19:13:07.771892480       3.125914
# ...

# %%
top_products = df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10)
top_products
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# REGENCY CAKESTAND 3 TIER              142264.75
# WHITE HANGING HEART T-LIGHT HOLDER    100392.10
# JUMBO BAG RED RETROSPOT                85040.54
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# POSTAGE                                77803.96
# PARTY BUNTING                          68785.23
# ASSORTED COLOUR BIRD ORNAMENT          56413.03
# Manual                                 53419.93
# RABBIT NIGHT LIGHT                     51251.24
# Name: Revenue, dtype: float64

# %%
top_customers = df.groupby("CustomerID")["Revenue"].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# CustomerID
# 14646    280206.02
# 18102    259657.30
# 17450    194390.79
# 16446    168472.50
# 14911    143711.17
# 12415    124914.53
# 14156    117210.08
# 17511     91062.38
# 16029     80850.84
# 12346     77183.60
# Name: Revenue, dtype: float64

# %%
country_revenue = df.groupby("Country")["Revenue"].sum().sort_values(ascending=False)
country_revenue
# Out:
# Country
# United Kingdom          7285024.644
# Netherlands              285446.340
# EIRE                     265262.460
# Germany                  228678.400
# France                   208934.310
# Australia                138453.810
# Spain                     61558.560
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38367.830
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33375.840
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20440.540
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13502.850
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7215.840
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# USA                        3580.390
# ...

# %%
df["YearMonth"] = df["InvoiceDate"].dt.to_period("M")

monthly_revenue = df.groupby("YearMonth")["Revenue"].sum()

monthly_revenue.plot()
# Out:
# <Axes: xlabel='YearMonth'>
