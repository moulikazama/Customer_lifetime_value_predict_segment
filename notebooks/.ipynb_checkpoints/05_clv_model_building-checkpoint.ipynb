# %%
# 05_clv_model_building

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rfm = pd.read_csv('../data/rfm_data.csv')
rfm.head()
# Out:
#    Recency  Frequency  Monetary  R_score  F_score  M_score  RFM_Score  \
# 0      326          1  77183.60        1        1        5        115
# 1        2          7   4310.00        5        5        5        555
# 2       75          4   1437.24        2        4        4        244
# 3       19          1   1457.55        4        1        4        414
# 4      310          1    294.40        1        1        2        112
#
#                Segment
# 0                 Lost
# 1            Champions
# 2      Loyal Customers
# 3  Potential Loyalists
# 4                 Lost

# %%
rfm['AOV'] = rfm['Monetary'] / rfm['Frequency']
rfm.head()
# Out:
#    Recency  Frequency  Monetary  R_score  F_score  M_score  RFM_Score  \
# 0      326          1  77183.60        1        1        5        115
# 1        2          7   4310.00        5        5        5        555
# 2       75          4   1437.24        2        4        4        244
# 3       19          1   1457.55        4        1        4        414
# 4      310          1    294.40        1        1        2        112
#
#                Segment           AOV
# 0                 Lost  77183.600000
# 1            Champions    615.714286
# 2      Loyal Customers    359.310000
# 3  Potential Loyalists   1457.550000
# 4                 Lost    294.400000

# %%
rfm['Purchase_Frequency'] = rfm['Frequency']

# %%
rfm['Lifespan_Score'] = 365 - rfm['Recency']

# %%
rfm['CLV'] = rfm['AOV'] * rfm['Purchase_Frequency'] * (rfm['Lifespan_Score'] / 365)
rfm.head()
# Out:
#    Recency  Frequency  Monetary  R_score  F_score  M_score  RFM_Score  \
# 0      326          1  77183.60        1        1        5        115
# 1        2          7   4310.00        5        5        5        555
# 2       75          4   1437.24        2        4        4        244
# 3       19          1   1457.55        4        1        4        414
# 4      310          1    294.40        1        1        2        112
#
#                Segment           AOV  Purchase_Frequency  Lifespan_Score  \
# 0                 Lost  77183.600000                   1              39
# 1            Champions    615.714286                   7             363
# 2      Loyal Customers    359.310000                   4             290
# 3  Potential Loyalists   1457.550000                   1             346
# 4                 Lost    294.400000                   1              55
#
#            CLV
# 0  8247.014795
# 1  4286.383562
# 2  1141.916712
# 3  1381.677534
# 4    44.361644

# %%
rfm.groupby('Segment')['CLV'].mean().plot(kind='bar')
plt.title('Average CLV by Segment')
plt.ylabel('Average CLV')
plt.xticks(rotation=45)
plt.show()

# %%
rfm.groupby('Segment')[['Monetary','CLV']].mean()
# Out:
#                         Monetary          CLV
# Segment
# At Risk               877.853132   501.726028
# Champions            5130.175070  4998.276206
# Lost                  477.678062   190.524699
# Loyal Customers      2035.321906  1566.526305
# Need Attention        848.291637   780.173551
# Potential Loyalists   446.169122   423.787324

# %%
rfm.to_csv("../data/rfm_with_clv.csv", index=False)
